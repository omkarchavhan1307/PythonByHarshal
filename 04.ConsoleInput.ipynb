# %% [markdown]
# Output

# %%
print("Welcome to Python")
# Out:
# Welcome to Python

# %% [markdown]
# Input

# %%
# variable = input("Message") 
# print(variable)


user_input = input("enter your name")
print(user_input)
# Out:
# Komal

# %% [markdown]
# Type Conversion

# %%
# age = input("Age : ")
# price = input("Price : ") 

# print(type(age))      # str
# print(type(price))    # str

num1 = int(input("enter num 1"))   # 10  - "10"
num2 = int(input("enter num 2"))   # 20  - "20"

res = num1 + num2
print(res)                    # 1020


# age = int(input("Age : ")) 
# price = float(input("Price : ")) 

# print(age)
# print(price)
# print(type(age))
# print(type(price))
# Out:
# 20

# %% [markdown]
#  Formatting Output

# %%
age = int(input("Age : ")) 
price = float(input("Price : ")) 

print("Age of user is :",age)
print("Price of product is :",price)
# Out:
# Age of user is : 23
# Price of product is : 1000.0
