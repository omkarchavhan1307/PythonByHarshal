# %%
StudentName = "Demo"
StudentSurname = 'user'

studentInfo="""demo 
user 
dfghjkl
dfghjkl;"""

studentAdd = '''demo user
live in pune'''

print(StudentName)
print(StudentSurname)

print(studentInfo)
print(studentAdd)
# Out:
# Demo
# user
# demo
# user
# dfghjkl
# dfghjkl;
# demo user
# live in pune

# %%
userName = "demo"

print(userName)
print(id(userName))

userName = "user"



str1 = userName.isnumeric()

print(userName)
print(id(userName))
print(str1)
# Out:
# demo
# 2317662935760
# user
# 2317595941824
# False

# %%
userName = "demouser"
#           01234567

# print(userName[1])


print(userName[0:4])
print(userName[0:4:1])
print(userName[0:])
print(userName[:4])
print(userName[:])
print(userName[::-1])

# [ start : end : step]
# Out:
# demo
# demo
# demouser
# demo
# demouser
# resuomed

# %%
userName = "demouser"

temp = userName[::-1]

for i in temp:
    print(i)
# Out:
# r
# e
# s
# u
# o
# m
# e
# d

# %%
userName = "demouser123"

print(userName)
# print("3" + 3 )
# Out:
# demouser123

# %%
userName = "demouser"
#           01234567         positive indexing
# --------->
#         -5-4-3-2-1         negative indexing
#  <-----------

print(userName[7])
print(userName[-3])
# Out:
# r
# s

# %%
str1 = "demo"
str2 = "user"

fullname = str1 + str2
print(fullname)

print(str1 + str2)
# Out:
# demouser
# demouser

# %% [markdown]
# String Methods

# %%
str1 = "Demo user live in pune"

temp ="   demo     "

# print(str1.upper())
# print(str1.lower())

# print(str1.capitalize())
# print(str1.title())

# print(str1.swapcase())

print(str1)
print(temp)

print(temp.lstrip())
print(temp.rstrip())
print(temp.strip())
# Out:
# Demo user live in pune
#    demo
# demo
#    demo
# demo

# %%
str1 = "Demo"

print(str1)

print(str1.replace("e","z"))
# Out:
# Demo
# Dzmo

# %%
str1 = "Demo user live in pune"

# print(str1.split( seperater ))
print(str1.split())
# Out:
# ['Demo', 'user', 'live', 'in', 'pune']

# %%
listOne = ['Demo', 'user', 'live', 'in', 'pune',"1"]

# demo = "Demo user live in pune 1"

# listOne = [1,2,3,4,5]

temp = " ".join(listOne)

print(temp)

print(" ".join(listOne))

print(len(listOne))
print(len(temp))
# Out:
# Demo user live in pune 1
# Demo user live in pune 1
# 6
# 24

# %%
str1 = "demo111"

# print(demo.find("z"))

# print(demo.index("z"))

# print(str1.count("o"))

# print(str1.startswith("z"))

# print(str1.endswith("d"))

print(str1.isalpha())   # complete alphabate

print(str1.isdigit())  # complete Digits/number

print(str1.isalnum()) # Mix
# Out:
# False
# False
# True

# %% [markdown]
# Built-in Functions

# %%
str1 = "doem"
str2 = "12734"

temp = "neha"

print(ord("n"),ord("e"),ord("h"),ord("a"))

#variabeName.method()

# functionName(varibale)

# print(len(str1))

# max - return maximum value

print(ord("d"))
print(ord("e"))
print(ord("m"))
print(ord("o"))





print(max(str1))
print(max(str2))


print(chr(100))
print(chr(110),chr(101),chr(104),chr(97))
# Out:
# 110 101 104 97
# 100
# 101
# 109
# 111
# o
# 7
# d
# n e h a

# %%
# str1 = "demo"
str2 = "1234"


# print(min(str1))
# print(min(str2))

# print(sorted(str2))

# print(type(str2))

# print(list(str1))

# print(tuple(str1))

# print(set(str1))

# for i ,j in enumerate(str1):
#     print(i,j)

# print("".join(reversed(str2)))

# True - False
#  1   -  0

# str1 = "demo0"

# print(any(str1))

# print(all(str1))

# listOne = [0,0,0,0,"demo"]

# print(any(listOne))


# listOne = ["demo",1,True,0]

# print(all(listOne))

# %%
temp = "demoUser"

# print(temp[-3])

print(temp[:2])

# dmue
# Out:
# de
