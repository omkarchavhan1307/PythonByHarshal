# %%
print("Hello World")
# Out:
# Hello World

# %%
name = "Omkar Santosh Chavhan"
age = "22"
college_name = "Genba Sopanrao Moze College Of Engineering, Balewadi, Pune."
city = "Pune"
course_name = "Agentic AI"

print("PERSONAL PROFILE")
print("Name :", name)
print("Age :", age)
print("College Name :", college_name)
print("City :", city)
print("Course Name :", course_name)
# Out:
# PERSONAL PROFILE
# Name : Omkar Santosh Chavhan
# Age : 22
# College Name : Genba Sopanrao Moze College Of Engineering, Balewadi, Pune.
# City : Pune
# Course Name : Agentic AI
