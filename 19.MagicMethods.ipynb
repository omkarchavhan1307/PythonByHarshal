# %%
class Demo:
    def __init__(self,num1):
        self.numone = num1

    def __str__(self):
        return self.numone

    def __len__(self):
        return len(self.numone)

    def __eq__(value1, value2):
        return value1.numone == value2.numone
        
# obj1 = Demo("10")
obj1 = Demo("demo")
obj2 = Demo("demo")

print(obj1)

print(len(obj1))

print(obj1 == obj2)
# Out:
# demo
# 4
# True

# %%
class Temp:
    def __init__(self,num1):
        self.numone = num1

    def __add__(value1 , value2):
        return value1.numone + value2.numone
             #    40           +   20

    def __sub__(value1 , value2):
        return value1.numone - value2.numone
        #    10           +   20

    def __mul__(value1 , value2):
        return value1.numone * value2.numone

    def __truediv__(self, other):
        return self.numone / other.numone

    def __floordiv__(self, other):
        return self.numone // other.numone

    def __mod__(self, other):
        return self.numone % other.numone

obj1 = Temp(44)
obj2 = Temp(10)

print( obj1 + obj2)
print( obj1 - obj2)
print(obj1 * obj2)
print(obj1/obj2)
print(obj1//obj2)
print(obj1%obj2)
# Out:
# 54
# 34
# 440
# 4.4
# 4
# 4

# %%
class Demo:
    def __init__(self,str1):
        # print("hello this is magic method")
        self.tempstr = str1

    def __str__(self):
        return self.tempstr

    def display(self):
        print("hello this is normal method")

    
obj1 = Demo("demouser") 

print(obj1)


# obj1.display()
# Out:
# demouser

# %%
def display():
        print("hello this is normal method")

display()
# Out:
# hello this is normal method

# %%
class Temp:
    def __init__(self,num1):
        self.numone = num1

    def __str__(self):
        return self.numone

    def __add__(value1,value2):        
        return Temp(value1.numone + value2.numone)
        


obj1 = Temp(10)
obj2 = Temp(20)
obj3 = Temp(30)

var1 = obj1 + obj2 + obj3


# print(obj1)
print(var1.numone)
# Out:
# 60

# %%
l1=[1,2,3 ,7]
l2=[4,5,6]

res = l1+l2

# print(res)      [1, 2, 3, 7, 4, 5,6]


#   6       % 2 
if len(res) % 2 == 0:
    indexnum = len(res) // 2
    # print(indexnum)   # 3

    num1 = res[indexnum]    #3
    num2 = res[indexnum-1]  #2

    # print(num1 , num2)

    addition = num1 + num2

    print(addition/2)

else:
    indexnum = len(res) // 2
    print(res[indexnum])
# Out:
# 7
