# %% [markdown]
# 1. Write a program to create a text file and store the name, age, and marks of a student in it.

# %%
name = input("Enter your name :")
age = int(input("Enter your age :"))
marks = int(input("Enter your marks :"))

with open("temp.txt", "w") as file:
    file.write("Name :" + name + "\n")
    file.write("Age :" + str(age) + "\n")
    file.write("Marks :" + str(marks) + "\n")

file.close()

print("Student dtails stored successfully..!")
# Out:
# Student dtails stored successfully..!

# %% [markdown]
# 2. Write a program to read the complete contents of a file and count the total number of characters.

# %%
with open("temp.txt", "r") as file:
    data = file.read()

print("File contents :")
print(data)

print("Total numbers of characters :", len(data))
# Out:
# File contents :
# Name :Omkar
# Age :22
# Marks :90
#
# Total numbers of characters : 30

# %% [markdown]
# 3. Write a program to read a file line by line and count the total number of lines.

# %%
with open("temp.txt", "r") as file:
    lines = file.readlines()
print("Lines in a file :")
print(lines)
print("Total number of lines :", len(lines))




# count = 0
# with open("temp.txt", "r") as file:
    
#     for line in file:
#             count += 1

#     print("Total number of lines :", count)
# Out:
# Lines in a file :
# ['Name :Omkar\n', 'Age :22\n', 'Marks :90\n']
# Total number of lines : 3

# %% [markdown]
# 4. Write a program to read a file and count the number of words present in it.

# %%
with open("temp.txt", "r") as file:
    data = file.read()

words = data.split()

print(words)
print("Total number of words :",len(words))
# Out:
# ['Name', ':Omkar', 'Age', ':22', 'Marks', ':90']
# Total number of words : 6

# %% [markdown]
# 5. Write a program to copy the contents of one text file into another file.

# %%
with open("temp.txt", "r") as file1:
    data = file1.read()

with open("temp1.txt", "w") as file2:
    file2.write(data)

print("Data copied successfully..!")
# Out:
# Data copied successfully..!

# %% [markdown]
# 6. Write a program to read a file and create another file containing only the lines that contain the word "Python".

# %%
with open("python.txt", "w") as file1:
    file1.write("Python is easy to learn.\n")
    file1.write("Java is also popular.\n")
    file1.write("I am learning Python.\n")
    file1.write("C++ is a programming language.\n")
    file1.write("Python is used in AI.\n")

file.close()

with open("python.txt", "r") as file1:
    with open("python_lines.txt", "w") as file2:
        for line in file1:
            if "Python" in line:
                file2.write(line)

print("File containing only the lines that contain word 'Python' is created..!")
# Out:
# File containing only the lines that contain word 'Python' is created..!

# %% [markdown]
# 7. Write a program to append new student records to an existing file without deleting the previous records.

# %%
name = input("Enter your name :")
age = int(input("Enter your age :"))
marks = int(input("Enter your marks :"))

with open("temp.txt", "a") as file1:
    file1.write("Name :" + name +"\n") 
    file1.write("Age :" + str(age) +"\n")
    file1.write("Marks :" + str(marks) +"\n")

print("Student record adding successfully..!")
# Out:
# ---------------------------
# Student record adding successfully..!

# %% [markdown]
# 8. Write a program to read a file and find the longest word present in it.

# %%
with open("temp.txt", "a") as file1:
    file1.write("Python programming language\n")


with open("temp.txt", "r") as file:
    data = file.read()

words = data.split()

longest_word = max(words, key=len)

# longest_word = 0
# for word in words:
#     if len(word) > len(longest_word):
#         longest_word += 1

print("Longest word in the file is :",longest_word)
# Out:
# Longest word in the file is : programming

# %% [markdown]
# 9. Write a program to read a file containing numbers and calculate their sum, average, maximum, and minimum.

# %%
with open("numbers.txt", "w") as file1:
    file1.write("10\n")
    file1.write("20\n")
    file1.write("30\n")
    file1.write("40\n")
    file1.write("50\n")
    file1.write("60\n")
    file1.write("70\n")
    file1.write("80\n")
    file1.write("90")

with open("numbers.txt", "r") as file2:

    numbers = []

    for line in file2:
        numbers.append(int(line.strip()))

total = sum(numbers)
average = total / len(numbers)
maximum = max(numbers)
minimum = min(numbers)

print("Sum of numbers :", total)
print("Average :", average)
print("Maximum :", maximum)
print("Minimum :", minimum)
# Out:
# Sum: 450
# Average: 50.0
# Maximum: 90
# Minimum: 10
