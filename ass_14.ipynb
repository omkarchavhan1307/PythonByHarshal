# %% [markdown]
# 1. Student Information System Create a Student class with: • name  • roll_no  • branch  • marks
# -Create 3 student objects and create a method display() to print their details.

# %%
class Student :
    def __init__(self, name, roll_no, branch, marks):
        self.name = name
        self.roll_no = roll_no
        self.branch = branch
        self.marks = marks

    def display(self):
        print("Name :", self.name)
        print("Roll_no :", self.roll_no)
        print("Branch :", self.branch)
        print("Marks :", self.marks)
        print(" ")

Student1 = Student("Omkar", "08", "AI-DS", 98)
Student2 = Student("Komal", 21, "CS", 100)
Student3 = Student("Avishkar", 20, "IT", 99)


Student1.display()
Student2.display()
Student3.display()
# Out:
# Name : Omkar
# Roll_no : 08
# Branch : AI-DS
# Marks : 98
#
# Name : Komal
# Roll_no : 21
# Branch : CS
# Marks : 100
#
# Name : Avishkar
# Roll_no : 20
# Branch : IT
# Marks : 99

# %% [markdown]
# 2. Employee Salary Create an Employee class with: • name  • employee_id  • salary
# Create a method display_salary() that displays the employee's salary. Create 3 employee objects. : Don't assign the values directly inside the class. Pass them while creating objects.

# %%
class Employee:
    def __init__(self, name, employee_id, salary):
        self.name = name
        self.employee_id = employee_id
        self.salary = salary

    def display_salary(self):
        print("Name of employee is :",self.name)
        print("Employee_Id is :", self.employee_id)
        print("Salary of employee is :", self.salary)
        print(" ")

Employee1 = Employee("Omkar", 1001, 50000)
Employee2 = Employee("Swapnil", 1002, 60000)
Employee3 = Employee("Sarthak", 1003, 30000)

Employee1.display_salary()
Employee3.display_salary()
Employee2.display_salary()
# Out:
# Name of employee is : Omkar
# Employee_Id is : 1001
# Salary of employee is : 50000
#
# Name of employee is : Sarthak
# Employee_Id is : 1003
# Salary of employee is : 30000
#
# Name of employee is : Swapnil
# Employee_Id is : 1002
# Salary of employee is : 60000

# %% [markdown]
# 3. Mobile Phone Create a Mobile class with: • brand  • model  • price
# Create a method: display_details() Create 3 mobile objects with different information. Expected concept: Constructor + objects.

# %%
class Mobile:
    def __init__(self, brand, model, price):
        self.brand = brand
        self.model = model
        self.price = price

    def display_details(self):
        print("Mobile brand is :",self.brand)
        print("Model of mobile is :",self.model)
        print("Price of mobile is :",self.price)
        print(" ")

Mobile1 = Mobile("Apple", "15-pro", 64000)
Mobile2 = Mobile("Samsung", "S23 ultra", 150000)
Mobile3 = Mobile("RealMe", "Narzo10", 13000)

Mobile1.display_details()
Mobile2.display_details()
Mobile3.display_details()
# Out:
# Mobile brand is : Apple
# Model of mobile is : 15-pro
# Price of mobile is : 64000
#
# Mobile brand is : Samsung
# Model of mobile is : S23 ultra
# Price of mobile is : 150000
#
# Mobile brand is : RealMe
# Model of mobile is : Narzo10
# Price of mobile is : 13000
