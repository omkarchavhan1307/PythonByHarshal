# %%
# Read the file
file = open("temp.txt", "r")
data = file.read()
print(data)

file.close()
# Out:
# name = Omkar

# %%
file = open("temp1.txt", "w")
data = file.write("Hello Omkar")

file.close()

# %%
file = open("temp1.txt", "a")
data = file.write("Hello Komal")

file.close()

# %%
ListOne = ["Omkar\n","Komal\n","Vikrant\n","Nikhil"]
file = open("temp2.txt", "w")
data = file.writelines(ListOne)

file.close()
