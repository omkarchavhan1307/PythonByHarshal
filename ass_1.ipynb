# %%
name = "Omkar Santosh Chavhan"
age = "22"
college_name = "Genba Sopanrao Moze College Of Engineering, Balewadi, Pune."
city = "Pune"
course_name = "Agentic AI"

print("PERSONAL PROFILE")
print("Name :", name)
print("Age :", age)
print("College Name :", college_name)
print("City :", city)
print("Course Name :", course_name)
# Out:
# PERSONAL PROFILE
# Name : Omkar Santosh Chavhan
# Age : 22
# College Name : Genba Sopanrao Moze College Of Engineering, Balewadi, Pune.
# City : Pune
# Course Name : Agentic AI

# %%
student_name = "Omkar Santosh Chavhan"
roll_number = "08"
branch = "Artificial Intelligence and Data Science"
percentage = "85 %"
passed = True

print("STUDENT REPORT")
print("Student Name :", student_name)
print("Roll Number :", roll_number)
print("Branch :", branch)
print("Percentage :", percentage)
print("Passed :", passed)
# Out:
# STUDENT REPORT
# Student Name : Omkar Santosh Chavhan
# Roll Number : 08
# Branch : Artificial Intelligence and Data Science
# Percentage : 85 %
# Passed : True

# %%
student_name = "Omkar"
roll_no = "08"
college_name = "Genba Sopanrao Moze College Of Engineering, Balewadi, Pune."
branch = "Artificial Intelligence and Data Science"
semester = "8 th"
attendance = "92 %"
cgpa = 8.65
fees_paid = True
mobile_number = "8080085552"
email_id = "ochavhan02@gmail.com"

print("Student Name :", student_name)
print("Roll No      :", roll_no)
print("College Name :", college_name)
print("Branch       :", branch)
print("Semester     :", semester)
print("Attendance   :", attendance)
print("CGPA         :", cgpa)
print("Fees Paid    :", fees_paid)
print("Mobile No    :", mobile_number)
print("Email ID     :", email_id)
# Out:
# Student Name : Omkar
# Roll No      : 08
# College Name : Genba Sopanrao Moze College Of Engineering, Balewadi, Pune.
# Branch       : Artificial Intelligence and Data Science
# Semester     : 8 th
# Attendance   : 92 %
# CGPA         : 8.65
# Fees Paid    : True
# Mobile No    : 8080085552
# Email ID     : ochavhan02@gmail.com

# %%
# This program prints my introduction.
# My name is Omkar.
# I am learning Python.
# I enjoy programming.

"""
This is a multi-line comment.
It describes the purpose of the program.
Python supports documentation using triple quotes.
"""

print("Hello!")
print("My name is Omkar Santosh Chavhan.")
print("I am pursuing B.E. in Artificial Intelligence and Data Science.")
print("I live in Pune.")
print("I enjoy coding and learning new technologies.")
# Out:
# Hello!
# My name is Omkar Santosh Chavhan.
# I am pursuing B.E. in Artificial Intelligence and Data Science.
# I live in Pune.
# I enjoy coding and learning new technologies.

# %%
"""2name  =>	name2
student-name  =>	student_name
class =>	class_name
my name	 =>  my_name
roll.no   =>	roll_no
@email	=>  email
first name	=>   first_name
college-name  =>	college_name
123abc	=>   abc123
pass  =>	is_passed
"""
name2 = "Omkar"
student_name = "Omkar"
class_name = "B.E."
my_name = "Omkar Santosh Chavhan"
roll_no = "08"
email = "ochavhan02@gmail.com"
first_name = "Omkar"
college_name = "GSMCOE"
abc123 = 123
is_passed = True

print(name2)
print(student_name)
print(class_name)
print(my_name)
print(roll_no)
print(email)
print(first_name)
print(college_name)
print(abc123)
print(is_passed)
# Out:
# Omkar
# Omkar
# B.E.
# Omkar Santosh Chavhan
# 08
# ochavhan02@gmail.com
# Omkar
# GSMCOE
# 123
# True
