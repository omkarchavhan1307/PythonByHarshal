# %% [markdown]
# 1. Find starting index of str2 in str1.

# %%
str1 = "user Demo User Demo"
str2 = "Demo"

# if str2 in str2:
#     for i in range(len(str1)):
#         if str1[i : i + len(str2)] == str2:
#             print("str2 starts from index :", i)

#             break


# if str2 in str2:
#     for i in range(len(str1)):
#         if str1.startswith(str2,i):
#             print("str2 starts from index :", i)

#             break

if str2 in str2:
    index = str1.find(str2)
    print("str2 starts from index :", index)

else:
    print("Not found.")
# Out:
# str2 starts from index : 5

# %% [markdown]
# 2. Find middle of two lists.If two element is their then find avg between them.

# %%
listone = [1,2,3,4]
listtwo = [5,6,8,10,11]

listone.extend(listtwo)

print(listone)

if len(listone) % 2 == 1:
    middle = len(listone) // 2
    print("Middle element is :",listone[middle])

else:
    middle = len(listone) // 2
    previous = middle + 1
    median = (listone[middle] + listone[previous]) / 2    

    print("Middle number is :",median)
# Out:
# [1, 2, 3, 4, 5, 6, 8, 10, 11]
# Middle element is : 5

# %% [markdown]
# 3. move_zeroes(nums). -Input : [0, 1, 0, 3, 12] -Output : [1, 3, 12, 0, 0]

# %%
ListOne = [0, 1, 0, 3, 12]

non_zero = []
zero = []

for i in ListOne:
    if i == 0:
        zero.append(i)

    else:
        non_zero.append(i)


# print(zero)
# print(non_zero)
print(non_zero + zero)
# Out:
# [1, 3, 12, 0, 0]

# %% [markdown]
# 4. Remove character.
# -Input : s = "banana". Remove "a" character.

# %%
# s = "banana"

# s1 = s.replace("a","")      # replace("what is replace , by which ")

# print(s1)


s = "banana"

char = "a"

ListOne = []

for i in s:
    if i == char:
        pass
    else:
        ListOne.append(i)

res = "".join(ListOne)

print(res)
# Out:
# bnn

# %% [markdown]
# 5. Str1 = "   Hello this is a magic method    ".  Find length of last word "method".

# %%
str1 = "   Hello this is a magic method    "

str2 = str1.strip()

str3 = str2.split()

print(str1)
print(" ")
print(str2)
print(" ")
print(str3)
print(" ")
print("Length of last word is :",len(str3[-1]))
# Out:
#    Hello this is a magic method
#
# Hello this is a magic method
#
# ['Hello', 'this', 'is', 'a', 'magic', 'method']
#
# Length of last word is : 6

# %% [markdown]
# 6. Input : aaaabbcccc  -Output : ccccaaaabb

# %%
# str1 = "aaaabbcccc"

# str2 = []
# str3 = []

# for i in str1:
#     if i == "c":
#         str2.append(i)

#     else:
#         str3.append(i)

# print("".join(str2 + str3))


# str1 = "aaaabbcccc"

# ch = str1[-1]
# front = []
# back = []

# for i in str1:
#     if i == ch:
#         front.append(i)

#     else:
#         back.append(i)


# print("".join(front + back))

# input - aaabbbbccccc
# o/p  - cccccaaabbbb

input = "aaabccbbbccccc"
list1  = []
list2 = []

for i in range(len(input)-1, 0, -1):
    if input[i] == input[i-1]:
        list1.append(input[i])
    else:
        list1.append(input[i])
        break


for i in range(len(input) - len(list1)):
    list2.append(input[i])
    
list1.extend(list2)

output = "".join(list1)
# print(list1)
print("Output = ",output)
# Out:
# Output =  cccccaaabccbbb

# %% [markdown]
# 7. -Input : "abcdefgh" -Output : "dcbahgfe"

# %%
str1 = "abcdefghijkl"
slice1 = []

if len(str1) % 4 == 0:
    print("Divisible by 4.")
    for i in range(0, len(str1), 4):
        slice1 += (str1[i:i+4][::-1])
        print("".join(slice1))
else:
    print("Not divisible by 4.")
# Out:
# Divisible by 4.
# dcba
# dcbahgfe
# dcbahgfelkji

# %% [markdown]
# 8. str1 = "python" -O/P : ononon

# %%
str1 = "pythona"

a = str1[-2]   # n
b = str1[-1]   # a

res = ""
 
for i in range(len(str1)):
    if i % 2 == 0:
        res += a

    else:
        res += b

print(res)
# Out:
# nananan

# %% [markdown]
# 9. Create a function which store a parameters ("[[]]", ("abc")). -Output : [[abc]]

# %%
def Demo(num1, num2):
    res1 = num1[:len(num1) // 2] 
    res2 = num2
    res3 = num1[(len(num1) // 2):]


    print("Output is :", f"{res1}{res2}{res3}")

Demo("[[]]", "abc")
# Out:
# Output is : [[abc]]

# %% [markdown]
# 10. Remove duplicates from a string and print it into alphabetical order.

# %%
str1 = "My name is Omkar and my wife name is Komal"

str2 = ""
str3 = ""
for i in str1:
    if i == " ":
        str2 += i

    else:
        str3 += i

str4 = str3.lower()

str5 = list(set(str4))

print("".join(sorted(str5)))
# Out:
# adefiklmnorswy

# %% [markdown]
# 11. Majority element. If 2 elements have equal count then you have to find greatest number from them.

# %%
numbers = [3,2,3,2,3,4,2,4,3,2]
majority_count = 0
largest_element = None

for i in numbers:
    frequency = numbers.count(i)

    if frequency > majority_count:
        majority_count += frequency
        largest_element = i

print("Maximum frequency :",majority_count)
print("Largest element is :", largest_element)
# Out:
# Maximum frequency : 4
# Largest element is : 3

# %% [markdown]
# 12. input- ["Flower", "Flight", "Fly"] -output : Fl

# %%
ListOne = ["Flower", "Flight", "Fly"]
check = []

for i in range(len(ListOne[0])):
    element = ListOne[0][:i+1]

    if all(i.startswith(element) for i in ListOne):
        check = element
    else:
        # temp = "Elements not start with same letters."
        # print(temp)
        break

print(check)
# Out:
# Fl

# %% [markdown]
# 13. Find longest sorted sequence without using built-in functions.

# %%
listone = [15,500, 10, 1, 11, 3, 12, 2, 4, 13, 501, 502, 504, 14, 503]

sequences = []
current = [listone[0]]

for i in range(len(listone)):
    for j in range(i + 1, len(listone)):
        if listone[i] > listone[j]:
            listone[i], listone[j] = listone[j], listone[i]

for i in range(1, len(listone)):
    if listone[i] == listone[i - 1] + 1:
        current.append(listone[i])
    else:
        sequences.append(current)
        current = [listone[i]]       

sequences.append(current)

print("Sequences:", sequences)

longest = max(sequences, key=len)

print("Longest sequence:", longest)
print("Length:", len(longest))
# Out:
# Sequences: [[15, 2, 3, 4], [10, 11, 12, 13, 14, 15], [500, 501, 502, 503, 504]]
# Longest sequence: [10, 11, 12, 13, 14, 15]
# Length: 6

# %%
ListOne = [15,500, 10, 1, 11, 3, 12, 2, 4, 13, 501, 502, 504, 14, 503]
# 500 > 1 = true = [1, 500, 3, 2, 4, 501, 502, 504, 503]
# 

for j in range(len(ListOne)-1):
    for i in range(len(ListOne) - 1):
        if ListOne[i] > ListOne[i+1]:
            minnum = ListOne[i+1]
            ListOne[i + 1] = ListOne[i]
            ListOne[i] = minnum

SortedList = ListOne
# print(SortedList)
# [1, 2, 3, 4, 500, 501, 502, 503, 504]
key = 0
dict1 = {}
ListTwo = []

for i in range(len(SortedList)-1):
    if SortedList[i] == SortedList[i + 1] -1:
        ListTwo.append(SortedList[i])
    else:
        ListTwo.append(SortedList[i])
        dict1[key] = ListTwo
        ListTwo = [ ]
        key += 1


ListTwo.append(SortedList[-1])
dict1[key] = ListTwo

# print(dict1)
# {0: [1, 2, 3, 4], 1: [500, 501, 502, 503, 504]}

Finaldict = dict1

Maxlengthlist = []

for k,v in Finaldict.items():
    Maxlengthlist.append(len(v))

# print(Maxlengthlist)

for i in range(len(Maxlengthlist)):
    for j in range(len(Maxlengthlist)-1):
        if Maxlengthlist[j] > Maxlengthlist[j+1]:
            Smallest = Maxlengthlist[j+1]
            Maxlengthlist[j+1] = Maxlengthlist[j]
            Maxlengthlist[j] = Smallest

# print(Maxlengthlist)

Maxlength = Maxlengthlist[-1]

# print(Maxlength)

FinalResult = [ ]

for k,v in Finaldict.items():
    if Maxlength == len(v):
        FinalResult.append(v)


print("Length of maximum sequence is :",Maxlength)
print("Sequence is :",FinalResult[0])
# Out:
# Length of maximum sequence is : 6
# Sequence is : [10, 11, 12, 13, 14, 15]
